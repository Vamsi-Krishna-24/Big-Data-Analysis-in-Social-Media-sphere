# %%
import pandas as pd

# %%
d1 = pd.read_csv("/Users/surisettivamsikrishna/Desktop/updated3 3.csv")

# %%
d1
# Out:
#      Unnamed: 0.1  Unnamed: 0                            Content ID  \
# 0               0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2               2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3               3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4               4           4  01ab84dd-6364-4236-abbb-3f237db77180
# ..            ...         ...                                   ...
# 796           994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 797           996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 798           997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 799           998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 800           999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category  Unnamed: 6
# ...

# %%
d1.drop(['Unnamed: 6'],axis=1)
# Out:
#      Unnamed: 0.1  Unnamed: 0                            Content ID  \
# 0               0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2               2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3               3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4               4           4  01ab84dd-6364-4236-abbb-3f237db77180
# ..            ...         ...                                   ...
# 796           994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 797           996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 798           997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 799           998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 800           999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# ...

# %%
d1.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                            Content ID  \
# 0             0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  Unnamed: 6
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying         NaN
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating         NaN
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating         NaN
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology         NaN
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food         NaN

# %%
d2 = pd.read_csv("/Users/surisettivamsikrishna/Desktop/updated.csv")

# %%
d2
# Out:
#        Unnamed: 0.1  Unnamed: 0                            Content ID  \
# 0                 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1                 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2                 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3                 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4                 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...             ...         ...                                   ...
# 22529         25547       25547  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22530         25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22531         25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22532         25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 22533         25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# ...

# %%
d1.merge(d2,how='inner',on='Content ID')
# Out:
#        Unnamed: 0.1_x  Unnamed: 0_x                            Content ID  \
# 0                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...               ...           ...                                   ...
# 18379             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x Type_x    Category  Unnamed: 6  \
# ...

# %%
d1.drop(columns=['Unnamed: 6'])
# Out:
#      Unnamed: 0.1  Unnamed: 0                            Content ID  \
# 0               0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2               2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3               3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4               4           4  01ab84dd-6364-4236-abbb-3f237db77180
# ..            ...         ...                                   ...
# 796           994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 797           996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 798           997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 799           998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 800           999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# ...

# %%
d1.merge(d2,how='inner',on='Content ID')
# Out:
#        Unnamed: 0.1_x  Unnamed: 0_x                            Content ID  \
# 0                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...               ...           ...                                   ...
# 18379             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x Type_x    Category  Unnamed: 6  \
# ...

# %%
pd.value_counts(data['Datetime'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Datetime'
#
# ...

# %%
data = d1.drop(columns=['Unnamed: 6'])

# %%
data
# Out:
#      Unnamed: 0.1  Unnamed: 0                            Content ID  \
# 0               0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2               2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3               3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4               4           4  01ab84dd-6364-4236-abbb-3f237db77180
# ..            ...         ...                                   ...
# 796           994         994  c54b49c4-b1f2-4641-8595-1cbd19937845
# 797           996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 798           997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 799           998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 800           999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type        Category
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# ...

# %%
data.merge(d2,how='inner',on='Content ID')
# Out:
#        Unnamed: 0.1_x  Unnamed: 0_x                            Content ID  \
# 0                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4                   0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...               ...           ...                                   ...
# 18379             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18380             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18381             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18382             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
# 18383             999           999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID_x Type_x    Category  \
# ...

# %%
data.to_csv(r"/Users/surisettivamsikrishna/Desktop/socialbuzz2.csv",index=False)

# %%
pd.value_counts(data['Category'])
# Out:
# Category
# travel             60
# science            55
# fitness            54
# animals            54
# culture            54
# technology         54
# tennis             53
# cooking            51
# healthy eating     50
# dogs               49
# education          48
# soccer             47
# food               47
# veganism           43
# studying           41
# public speaking    40
# Studying            1
# Name: count, dtype: int64

# %%
import pandas as pd
d3=pd.read_csv("/Users/surisettivamsikrishna/Desktop/updated1.csv")
d3
# Out:
#     Unnamed: 0.1  Unnamed: 0         Type Sentiment  Score
# 0              0           0        heart  positive     60
# 1              1           1         want  positive     70
# 2              2           2      disgust  negative      0
# 3              3           3         hate  negative      5
# 4              4           4   interested  positive     30
# 5              5           5  indifferent   neutral     20
# 6              6           6         love  positive     65
# 7              7           7   super love  positive     75
# 8              8           8      cherish  positive     70
# 9              9           9        adore  positive     72
# 10            10          10         like  positive     50
# 11            11          11      dislike  negative     10
# 12            12          12    intrigued  positive     45
# 13            13          13      peeking   neutral     35
# 14            14          14       scared  negative     15
# ...

# %%
d4=pd.read_csv('/Users/surisettivamsikrishna/Downloads/Reactions.csv')
d4
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2               2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3               3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4               4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ...           ...                                   ...
# 25548       25548  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25549       25549  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25550       25550  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25551       25551  75d6b589-7fae-4a6d-b0d0-752845150e56
# 25552       25552  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                     User ID        Type             Datetime
# 0                                       NaN         NaN  2021-04-22 15:17:15
# 1      5d454588-283d-459d-915d-c48a2cb4c27f     disgust  2020-11-07 09:43:50
# ...

# %%
d3.merge(d4,how='inner',on='Type')
# Out:
#        Unnamed: 0.1  Unnamed: 0_x     Type Sentiment  Score  Unnamed: 0_y  \
# 0                 0             0    heart  positive     60            24
# 1                 0             0    heart  positive     60            57
# 2                 0             0    heart  positive     60            70
# 3                 0             0    heart  positive     60            77
# 4                 0             0    heart  positive     60            87
# ...             ...           ...      ...       ...    ...           ...
# 24568            15            15  worried  negative     12         25416
# 24569            15            15  worried  negative     12         25423
# 24570            15            15  worried  negative     12         25463
# 24571            15            15  worried  negative     12         25547
# 24572            15            15  worried  negative     12         25551
#
#                                  Content ID  \
# ...

# %%
pd.value_counts(d4['Type'])
# Out:
# Type
# heart          1622
# scared         1572
# peeking        1559
# hate           1552
# interested     1549
# dislike        1548
# adore          1548
# want           1539
# love           1534
# disgust        1526
# like           1520
# super love     1519
# indifferent    1512
# cherish        1501
# worried        1497
# intrigued      1475
# Name: count, dtype: int64
